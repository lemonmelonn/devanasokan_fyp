# %%
import pandas as pd
from tqdm import tqdm
import time
import json
import ollama

# %%
df = pd.read_csv("C:/Users/User/Documents/devanasokan_fyp/storage/structured_verses.csv", encoding='utf-8-sig')

# %%
# Prompt template
def create_prompt(verse):

    prompt = f"""
You are an AI assistant helping with a dataset annotation task for a research project.

TASK: Your task is to classify song verses based on whether they are appropriate for children to listen to.

Label the verse as:

UNSAFE
* Sexual or suggestive content
* Explicit language or profanity
* References to drugs or alcohol

SAFE
* No mention of any topics listed above

Only respond with one word: SAFE or UNSAFE.




Verse:
"{verse}"
"""

    return prompt

# %%
labels = []

# Loop through dataset
for verse in tqdm(df["verses"]):

    try:

        response = ollama.chat(
            model="llama3",   # change if needed
            messages=[
                {"role": "user", "content": create_prompt(verse)}
            ]
        )

        label = response["message"]["content"].strip()

    except Exception as e:
        label = "ERROR"

    labels.append(label)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\User\Documents\devanasokan_fyp\.venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'verse'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 4
#       1 labels = []
# ...

# %%
print(labels)
# Out:
# ['SAFE', 'UNSAFE', 'SAFE', 'UNSAFE', 'SAFE', 'UNSAFE', 'UNSAFE', 'UNSAFE', 'SAFE', 'UNSAFE', 'SAFE', 'SAFE', 'SAFE', 'SAFE', 'SAFE', 'SAFE', 'UNSAFE', 'UNSAFE', 'UNSAFE', 'SAFE', 'SAFE', 'SAFE', 'SAFE', 'UNSAFE', 'SAFE', 'SAFE', 'SAFE', 'SAFE', 'SAFE', 'SAFE', 'UNSAFE', 'SAFE', 'SAFE', 'SAFE', 'SAFE', 'UNSAFE', 'SAFE', 'SAFE', 'SAFE', 'SAFE', 'SAFE', 'SAFE', 'SAFE', 'UNSAFE', 'SAFE', 'UNSAFE', 'SAFE', 'SAFE', 'SAFE', 'SAFE', 'SAFE', 'SAFE', 'UNSAFE', 'SAFE', 'SAFE', 'UNSAFE', 'SAFE', 'SAFE', 'SAFE', 'SAFE', 'UNSAFE', 'SAFE', 'UNSAFE', 'UNSAFE', 'SAFE', 'SAFE', 'SAFE', 'UNSAFE', 'UNSAFE', 'UNSAFE', 'UNSAFE', 'SAFE', 'UNSAFE', 'UNSAFE', 'UNSAFE', 'SAFE', 'SAFE', 'UNSAFE', 'SAFE', 'UNSAFE', 'SAFE', 'SAFE', 'SAFE', 'SAFE', 'SAFE', 'SAFE', 'SAFE', 'SAFE', 'SAFE', 'UNSAFE', 'SAFE', 'SAFE', 'SAFE', 'SAFE', 'SAFE', 'SAFE', 'SAFE', 'SAFE', 'SAFE', 'UNSAFE', 'UNSAFE', 'SAFE', 'UNSAFE', 'UNSAFE', 'SAFE', 'UNSAFE', 'SAFE', 'UNSAFE', 'SAFE', 'SAFE', 'SAFE', 'SAFE', 'SAFE', 'SAFE', 'SAFE', 'UNSAFE
# ...

# %%
# Add labels to dataframe
df["label"] = labels

# %%
# Save result
df.to_csv("labeled_songs.csv", index=False)
