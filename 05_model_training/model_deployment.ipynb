# %% [markdown]
# ### Model Deployment

# %%
from huggingface_hub import login, upload_folder, whoami
import os
from dotenv import load_dotenv
from transformers import AutoTokenizer, pipeline

# %%
# Load environment variables from .env
load_dotenv()

# Get the Hugging Face token from environment variables
HF_TOKEN = os.getenv("HUGGINGFACE_TOKEN")

# %%
# Login to Hugging Face Hub
login(token=HF_TOKEN)
print(whoami())  # Check if logged in successfully
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
# {'type': 'user', 'id': '68240b52ebd2cbe54da73677', 'name': 'devanasokan', 'fullname': 'Devan Asokan', 'isPro': False, 'avatarUrl': '/avatars/ee088b0bbacc155247b0ebe79d0e06ff.svg', 'orgs': [], 'auth': {'type': 'access_token', 'accessToken': {'displayName': 'fyp-deployment', 'role': 'fineGrained', 'createdAt': '2026-08-18T02:50:39.961Z', 'fineGrained': {'canReadGatedRepos': True, 'global': ['discussion.write'], 'scoped': [{'entity': {'_id': '68240b52ebd2cbe54da73677', 'type': 'user', 'name': 'devanasokan'}, 'permissions': ['repo.content.read', 'repo.access.read', 'repo.write', 'discussion.write']}]}}}}

# %%
# Model repository ID on Hugging Face Hub
repo_id = "devanasokan/bert-lyrics-classifier"

# %%
# Push model folder to HF Hub repo
upload_folder(
    folder_path="./my_final_bert",  # Your local folder path
    repo_id=repo_id,
    repo_type="model",
    commit_message="Upload BERT model"
)

print(f"Model pushed to: https://huggingface.co/{repo_id}")
# Out:
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# Model pushed to: https://huggingface.co/devanasokan/bert-lyrics-classifier

# %%
# Push tokenizer to HF Hub repo
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
tokenizer.push_to_hub(repo_id)

print(f"Tokenizer pushed to: https://huggingface.co/{repo_id}")
# Out:
# Tokenizer pushed to: https://huggingface.co/devanasokan/bert-lyrics-classifier

# %%
# TESTING THE DEPLOYED MODEL

# Import the pipeline for text classification
classifier = pipeline(
    "text-classification",
    model=repo_id,
)
# Out:
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]

# %%
# Test the deployed model with a sample input
result = classifier("(Metro)")
print(result)
# Out:
# [{'label': 'LABEL_0', 'score': 0.999535322189331}]
