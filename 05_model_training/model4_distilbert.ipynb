# %%
import pandas as pd
import torch
import os
import numpy as np

# %%
from datasets import Dataset
from transformers import BertTokenizer, TrainingArguments, Trainer
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\User\Documents\devanasokan_fyp\.venv\Lib\site-packages\transformers\utils\import_utils.py:2096, in _LazyModule.__getattr__(self, name)
#    2095 try:
# -> 2096     module = self._get_module(self._class_to_module[name])
#    2097     value = getattr(module, name)
#
# File c:\Users\User\Documents\devanasokan_fyp\.venv\Lib\site-packages\transformers\utils\import_utils.py:2290, in _LazyModule._get_module(self, module_name)
#    2289 except Exception as e:
# -> 2290     raise e
#
# File c:\Users\User\Documents\devanasokan_fyp\.venv\Lib\site-packages\transformers\utils\import_utils.py:2288, in _LazyModule._get_module(self, module_name)
#    2287 try:
# -> 2288     return importlib.import_module("." + module_name, self.__name__)
#    2289 except Exception as e:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:1026, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\User\Documents\devanasokan_fyp\.venv\Lib\site-packages\transformers\modeling_utils.py:72
#      71 from .integrations.flash_paged import paged_attention_forward
# ---> 72 from .integrations.flex_attention import flex_attention_forward
#      73 from .integrations.hub_kernels import allow_all_hub_kernels, is_kernel
#
# File c:\Users\User\Documents\devanasokan_fyp\.venv\Lib\site-packages\transformers\integrations\flex_attention.py:46
#      43 logger = logging.get_logger(__name__)
# ---> 46 class WrappedFlexAttention:
#      47     """
#      48     We are doing a singleton class so that flex attention is compiled once when it's first called.
#      49     """
#
# File c:\Users\User\Documents\devanasokan_fyp\.venv\Lib\site-packages\transformers\integrations\flex_attention.py:61, in WrappedFlexAttention()
#      59     return cls._instance
# ---> 61 @torch.compiler.disable(recursive=False)
#      62 def __init__(self, training):
#      63     """
#      64     Initialize or update the singleton instance.
#      65     """
#
# File c:\Users\User\Documents\devanasokan_fyp\.venv\Lib\site-packages\torch\compiler\__init__.py:240, in disable(fn, recursive)
#     232 """
#     233 This function provides a decorator to disable compilation on a function.
#     234 It also provides the option of recursively disabling called functions.
#    (...)    238     recursive (optional): A boolean value indicating whether the disabling should be recursive.
#     239 """
# --> 240 import torch._dynamo
#     242 return torch._dynamo.disable(fn, recursive)
#
# File c:\Users\User\Documents\devanasokan_fyp\.venv\Lib\site-packages\torch\_dynamo\__init__.py:13
#      11 import torch
# ---> 13 from . import config, convert_frame, eval_frame, resume_execution
#      14 from .backends.registry import list_backends, lookup_backend, register_backend
#
# File c:\Users\User\Documents\devanasokan_fyp\.venv\Lib\site-packages\torch\_dynamo\convert_frame.py:52
#      51 from torch._dynamo.distributed import get_compile_pg
# ---> 52 from torch._dynamo.symbolic_convert import TensorifyState
#      53 from torch._guards import compile_context, CompileContext, CompileId, tracing
#
# File c:\Users\User\Documents\devanasokan_fyp\.venv\Lib\site-packages\torch\_dynamo\symbolic_convert.py:57
#      55 from torch.utils._functools import cache_method
# ---> 57 from . import (
#      58     config,
#      59     exc,
#      60     graph_break_hints,
#      61     logging as torchdynamo_logging,
#      62     trace_rules,
#      63     variables,
#      64 )
#      65 from .bytecode_analysis import (
#      66     get_indexof,
#      67     JUMP_OPNAMES,
#      68     livevars_analysis,
#      69     propagate_line_nums,
#      70 )
#
# File c:\Users\User\Documents\devanasokan_fyp\.venv\Lib\site-packages\torch\_dynamo\trace_rules.py:32
#      31 from .utils import getfile, hashable, NP_SUPPORTED_MODULES, unwrap_if_wrapper
# ---> 32 from .variables import (
#      33     BuiltinVariable,
#      34     FunctionalCallVariable,
#      35     FunctorchHigherOrderVariable,
#      36     LocalGeneratorFunctionVariable,
#      37     LocalGeneratorObjectVariable,
#      38     NestedUserFunctionVariable,
#      39     PolyfilledFunctionVariable,
#      40     SkipFunctionVariable,
#      41     TorchInGraphFunctionVariable,
#      42     UserFunctionVariable,
#      43     UserMethodVariable,
#      44 )
#      47 np: Optional[types.ModuleType] = None
#
# File c:\Users\User\Documents\devanasokan_fyp\.venv\Lib\site-packages\torch\_dynamo\variables\__init__.py:19
#       1 """
#       2 This package implements variable tracking and symbolic execution capabilities for Dynamo,
#       3 which are essential for converting Python code into FX graphs. It provides a comprehensive
#    (...)     16 allows Dynamo to accurately trace and optimize Python code while preserving its semantics.
#      17 """
# ---> 19 from .base import VariableTracker
#      20 from .builtin import BuiltinVariable
#
# File c:\Users\User\Documents\devanasokan_fyp\.venv\Lib\site-packages\torch\_dynamo\variables\base.py:581
#     578         return " ".join(map(typestr, objs))
# --> 581 from . import builder
#
# File c:\Users\User\Documents\devanasokan_fyp\.venv\Lib\site-packages\torch\_dynamo\variables\builder.py:241
#     233 from .tensor import (
#     234     NumpyNdarrayVariable,
#     235     supported_const_comparison_op_values,
#    (...)    239     UnspecializedPythonVariable,
#     240 )
# --> 241 from .torch import (
#     242     DispatchKeySetVariable,
#     243     FuncTorchInterpreterVariable,
#     244     TorchCtxManagerClassVariable,
#     245     TorchInGraphFunctionVariable,
#     246 )
#     247 from .torch_function import (
#     248     build_torch_function_fn,
#     249     TensorWithTFOverrideVariable,
#     250     torch_function_mode_stack_state_mgr,
#     251     TorchFunctionModeVariable,
#     252 )
#
# File c:\Users\User\Documents\devanasokan_fyp\.venv\Lib\site-packages\torch\_dynamo\variables\torch.py:176
#     167 constant_fold_functions = dict.fromkeys(constant_fold_functions)
#     170 tracing_state_functions = {
#     171     torch.jit.is_scripting: False,
#     172     torch.jit.is_tracing: False,
#     173     torch._C._get_tracing_state: None,
#     174     torch.fx._symbolic_trace.is_fx_tracing: False,
#     175     torch.onnx.is_in_onnx_export: False,
# --> 176     torch._dynamo.external_utils.is_compiling: True,
#     177     torch._utils.is_compiling: True,
#     178     torch.compiler.is_compiling: True,
#     179     torch.compiler.is_dynamo_compiling: True,
#     180     torch.compiler.is_exporting: True,
#     181     torch.nn.modules.activation._is_make_fx_tracing: False,
#     182 }
#     184 bin_ops = dict.fromkeys(["add", "sub", "mul", "div", "sqrt"])
#
# AttributeError: partially initialized module 'torch._dynamo' from 'c:\Users\User\Documents\devanasokan_fyp\.venv\Lib\site-packages\torch\_dynamo\__init__.py' has no attribute 'external_utils' (most likely due to a circular import)
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\User\Documents\devanasokan_fyp\.venv\Lib\site-packages\transformers\utils\import_utils.py:2096, in _LazyModule.__getattr__(self, name)
#    2095 try:
# -> 2096     module = self._get_module(self._class_to_module[name])
#    2097     value = getattr(module, name)
#
# File c:\Users\User\Documents\devanasokan_fyp\.venv\Lib\site-packages\transformers\utils\import_utils.py:2290, in _LazyModule._get_module(self, module_name)
#    2289 except Exception as e:
# -> 2290     raise e
#
# File c:\Users\User\Documents\devanasokan_fyp\.venv\Lib\site-packages\transformers\utils\import_utils.py:2288, in _LazyModule._get_module(self, module_name)
#    2287 try:
# -> 2288     return importlib.import_module("." + module_name, self.__name__)
#    2289 except Exception as e:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:1026, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\User\Documents\devanasokan_fyp\.venv\Lib\site-packages\transformers\integrations\integration_utils.py:42
#      40     print("[INFO] Running in WANDB offline mode")
# ---> 42 from .. import PreTrainedModel, TrainingArguments
#      43 from .. import __version__ as version
#
# File c:\Users\User\Documents\devanasokan_fyp\.venv\Lib\site-packages\transformers\utils\import_utils.py:2184, in _LazyModule.__getattr__(self, name)
#    2183         else:
# -> 2184             raise ModuleNotFoundError(
#    2185                 f"Could not import module '{name}'. Are this object's requirements defined correctly?"
#    2186             ) from e
#    2188 elif name in self._modules:
#
# ModuleNotFoundError: Could not import module 'PreTrainedModel'. Are this object's requirements defined correctly?
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\User\Documents\devanasokan_fyp\.venv\Lib\site-packages\transformers\utils\import_utils.py:2096, in _LazyModule.__getattr__(self, name)
#    2095 try:
# -> 2096     module = self._get_module(self._class_to_module[name])
#    2097     value = getattr(module, name)
#
# File c:\Users\User\Documents\devanasokan_fyp\.venv\Lib\site-packages\transformers\utils\import_utils.py:2290, in _LazyModule._get_module(self, module_name)
#    2289 except Exception as e:
# -> 2290     raise e
#
# File c:\Users\User\Documents\devanasokan_fyp\.venv\Lib\site-packages\transformers\utils\import_utils.py:2288, in _LazyModule._get_module(self, module_name)
#    2287 try:
# -> 2288     return importlib.import_module("." + module_name, self.__name__)
#    2289 except Exception as e:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:1026, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\User\Documents\devanasokan_fyp\.venv\Lib\site-packages\transformers\trainer.py:39
#      37 # Integrations must be imported before ML frameworks:
#      38 # ruff: isort: off
# ---> 39 from .integrations import (
#      40     get_reporting_integration_callbacks,
#      41 )
#      43 # ruff: isort: on
#
# File c:\Users\User\Documents\devanasokan_fyp\.venv\Lib\site-packages\transformers\utils\import_utils.py:2184, in _LazyModule.__getattr__(self, name)
#    2183         else:
# -> 2184             raise ModuleNotFoundError(
#    2185                 f"Could not import module '{name}'. Are this object's requirements defined correctly?"
#    2186             ) from e
#    2188 elif name in self._modules:
#
# ModuleNotFoundError: Could not import module 'get_reporting_integration_callbacks'. Are this object's requirements defined correctly?
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 2
#       1 from datasets import Dataset
# ----> 2 from transformers import BertTokenizer, TrainingArguments, Trainer
#
# File c:\Users\User\Documents\devanasokan_fyp\.venv\Lib\site-packages\transformers\utils\import_utils.py:2184, in _LazyModule.__getattr__(self, name)
#    2180                     raise ModuleNotFoundError(
#    2181                         f"Could not import module '{name}'. Are this object's requirements defined correctly?"
#    2182                     ) from e
#    2183         else:
# -> 2184             raise ModuleNotFoundError(
#    2185                 f"Could not import module '{name}'. Are this object's requirements defined correctly?"
#    2186             ) from e
#    2188 elif name in self._modules:
#    2189     try:
#
# ModuleNotFoundError: Could not import module 'Trainer'. Are this object's requirements defined correctly?

# %%
df = pd.read_csv("C:/Users/User/Documents/devanasokan_fyp/preparation/modeldata.csv")

# %%
print(df.columns)
print(df.shape)
# Out:
# Index(['verse_id', 'song_id', 'ori_track_name', 'clean_track_name',
#        'all_artists', 'primary_artist', 'artist_genres', 'main_genre',
#        'explicit', 'section', 'verse', 'language', 'language.1', 'confidence',
#        'confidence.1', 'label'],
#       dtype='str')
# (22878, 16)

# %%
# Class balance check
print(df['label'].value_counts())
# Out:
# label
# 0    11439
# 1    11439
# Name: count, dtype: int64

# %%
# Select only the columns we need
df = df[['verse', 'label']]

# %%
# Convert to Hugging Face format
dataset = Dataset.from_pandas(df)

# %%
# Fixes the [WinError 3] by explicitly setting a local cache directory
cache_dir = "C:/Users/User/Documents/devanasokan_fyp/huggingface_cache"
if not os.path.exists(cache_dir):
    os.makedirs(cache_dir)

# %%
# Tell Hugging Face to use this directory
os.environ['HF_HOME'] = cache_dir

# This turns off the annoying symlink warning
os.environ['HF_HUB_DISABLE_SYMLINKS_WARNING'] = '1'

# %%
# Initiate with the cache path
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', cache_dir=cache_dir)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 # Initiate with the cache path
# ----> 2 tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', cache_dir=cache_dir)
#
# NameError: name 'BertTokenizer' is not defined

# %%
def preprocess_function(examples):
    # This creates the 'input_ids' and 'attention_mask' BERT needs
    return tokenizer(examples["verse"], truncation=True, padding="max_length", max_length=512)

tokenized_dataset = dataset.map(preprocess_function, batched=True)
# Out:
# Map: 100%|██████████| 22878/22878 [00:07<00:00, 3126.60 examples/s]

# %%
# 80% Train, 20% Test
full_dataset = tokenized_dataset.train_test_split(test_size=0.2, seed=42)

# %%
print(full_dataset) 
# If it shows {'train': ..., 'test': ...}, it is already split!
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['verse', 'label', '__index_level_0__', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 18302
#     })
#     test: Dataset({
#         features: ['verse', 'label', '__index_level_0__', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 4576
#     })
# })

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer

model_name = "distilbert-base-uncased" # Or any model from the Hugging Face Hub

# 1. Load the tokenizer (must match the model)
tokenizer = AutoTokenizer.from_pretrained(model_name)

# 2. Load the model with a classification head
model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=2)
# Out:
# Loading weights: 100%|██████████| 100/100 [00:00<00:00, 2609.40it/s]
# DistilBertForSequenceClassification LOAD REPORT from: distilbert-base-uncased
# Key                     | Status     |
# ------------------------+------------+-
# vocab_transform.bias    | UNEXPECTED |
# vocab_projector.bias    | UNEXPECTED |
# vocab_layer_norm.weight | UNEXPECTED |
# vocab_layer_norm.bias   | UNEXPECTED |
# vocab_transform.weight  | UNEXPECTED |
# classifier.bias         | MISSING    |
# classifier.weight       | MISSING    |
# pre_classifier.bias     | MISSING    |
# pre_classifier.weight   | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.

# %%
def model_init():
    return AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=2)

# %%
import evaluate
metric = evaluate.load("accuracy")

# %%
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    # argmax picks the highest probability (0 or 1)
    predictions = np.argmax(logits, axis=-1)
    return metric.compute(predictions=predictions, references=labels)

# %%
# Set training arguments
training_args = TrainingArguments(
    output_dir="./results",          # Folder where checkpoints are saved
    eval_strategy="epoch",           # Run evaluation after every epoch
    save_strategy="epoch",           # Save model after every epoch
    learning_rate=2e-5,               # Default value; overridden in the final run
    per_device_train_batch_size=16,   # Default value; overridden in the final run
    per_device_eval_batch_size=16,    # Batch size for evaluation
    num_train_epochs=2,               # Default value; overridden in the final run
    weight_decay=0.01,                # Regularization to prevent overfitting
    load_best_model_at_end=True,      # Keeps the best version of the model
    metric_for_best_model="accuracy",
    greater_is_better=True,
    report_to="none",
    fp16=torch.cuda.is_available()    # Use Mixed Precision if on GPU for 2x speed
)

# %%
trainer = Trainer(
    model_init=model_init,
    args=training_args,
    train_dataset=full_dataset["train"],
    eval_dataset=full_dataset["test"],
    compute_metrics=compute_metrics,
)

print(trainer.compute_metrics)
# Out:
# <function compute_metrics at 0x000001BA8F4CC680>

# %%
def hp_space(trial):
    return {
        "learning_rate": trial.suggest_float("learning_rate", 1e-5, 5e-5, log=True),
        "per_device_train_batch_size": trial.suggest_categorical(
            "per_device_train_batch_size", [8, 16]
        ),
        "num_train_epochs": trial.suggest_int("num_train_epochs", 2, 4),
        "weight_decay": trial.suggest_float("weight_decay", 0.0, 0.1),
    }

best_run = trainer.hyperparameter_search(
    direction="maximize",
    backend="optuna",
    hp_space=hp_space,
    n_trials=6,
    compute_objective=lambda metrics: metrics["eval_accuracy"],
)

print(best_run)
print(best_run.hyperparameters)

best_hyperparameters = best_run.hyperparameters
final_training_args = TrainingArguments(
    output_dir="./results",
    eval_strategy="epoch",
    save_strategy="epoch",
    learning_rate=best_hyperparameters["learning_rate"],
    per_device_train_batch_size=best_hyperparameters["per_device_train_batch_size"],
    per_device_eval_batch_size=16,
    num_train_epochs=best_hyperparameters["num_train_epochs"],
    weight_decay=best_hyperparameters["weight_decay"],
    load_best_model_at_end=True,
    metric_for_best_model="accuracy",
    greater_is_better=True,
    report_to="none",
    fp16=torch.cuda.is_available(),
)

final_trainer = Trainer(
    model=model_init(),
    args=final_training_args,
    train_dataset=full_dataset["train"],
    eval_dataset=full_dataset["test"],
    compute_metrics=compute_metrics,
)

final_trainer.train()
# Out:
#     <div>
#
#       <progress value='2288' max='2288' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2288/2288 19:56, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.221767</td>
#       <td>0.208492</td>
#       <td>0.923733</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.121560</td>
#       <td>0.284948</td>
#       <td>0.924170</td>
#     </tr>
#   </tbody>
# </table><p>
# Writing model shards: 100%|██████████| 1/1 [00:01<00:00,  1.87s/it]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.48it/s]
# There were missing keys in the checkpoint model loaded: ['distilbert.embeddings.LayerNorm.weight', 'distilbert.embeddings.LayerNorm.bias'].
# There were unexpected keys in the checkpoint model loaded: ['distilbert.embeddings.LayerNorm.beta', 'distilbert.embeddings.LayerNorm.gamma'].
# TrainOutput(global_step=2288, training_loss=0.16887637951990941, metrics={'train_runtime': 1196.9811, 'train_samples_per_second': 30.58, 'train_steps_per_second': 1.911, 'total_flos': 4848836660404224.0, 'train_loss': 0.16887637951990941, 'epoch': 2.0})

# %%
history = pd.DataFrame(final_trainer.state.log_history)
print(history)
# Out:
#        loss  grad_norm  learning_rate     epoch  step  eval_loss  \
# 0  0.219304  10.637142       0.000016  0.437063   500        NaN
# 1  0.221767  17.069284       0.000011  0.874126  1000        NaN
# 2       NaN        NaN            NaN  1.000000  1144   0.208492
# 3  0.148076  12.781887       0.000007  1.311189  1500        NaN
# 4  0.121560  11.472781       0.000003  1.748252  2000        NaN
# 5       NaN        NaN            NaN  2.000000  2288   0.284948
# 6       NaN        NaN            NaN  2.000000  2288        NaN
#
#    eval_accuracy  eval_runtime  eval_samples_per_second  \
# 0            NaN           NaN                      NaN
# 1            NaN           NaN                      NaN
# 2       0.923733       44.4181                  103.021
# 3            NaN           NaN                      NaN
# 4            NaN           NaN                      NaN
# 5       0.924170       40.4866                  113.025
# 6            NaN           NaN                      NaN
#
#    eval_steps_per_second  train_runtime  train_samples_per_second  \
# 0                    NaN            NaN                       NaN
# 1                    NaN            NaN                       NaN
# 2                  6.439            NaN                       NaN
# 3                    NaN            NaN                       NaN
# 4                    NaN            NaN                       NaN
# 5                  7.064            NaN                       NaN
# 6                    NaN      1196.9811                     30.58
#
#    train_steps_per_second    total_flos  train_loss
# 0                     NaN           NaN         NaN
# 1                     NaN           NaN         NaN
# 2                     NaN           NaN         NaN
# 3                     NaN           NaN         NaN
# 4                     NaN           NaN         NaN
# 5                     NaN           NaN         NaN
# 6                   1.911  4.848837e+15    0.168876

# %%
# Save the version currently in the final trainer's brain
final_trainer.save_model("./my_final_model")
# Out:
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  2.02it/s]

# %%
# TEST MODEL

from transformers import AutoModelForSequenceClassification, AutoTokenizer, pipeline

# Load the model and tokenizer from your local folder
path = "./my_final_model"
model = AutoModelForSequenceClassification.from_pretrained(path)
tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased") # Ensure you saved the tokenizer there too!

# Create a 'pipeline' (the easiest way to use the model)
classifier = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)
# Out:
# Loading weights: 100%|██████████| 104/104 [00:00<00:00, 5281.22it/s]

# %%
# Test it on a new sentence
result = classifier("kiss it from my lips")
print(result)
# Out:
# [{'label': 'LABEL_1', 'score': 0.968083381652832}]

# %%
import accelerate
print(accelerate.__version__)
# Out:
# 1.13.0

# %%
import accelerate
import transformers
print(f"Accelerate version: {accelerate.__version__}")
print(f"Transformers version: {transformers.__version__}")
# Out:
# Accelerate version: 1.13.0
# Transformers version: 5.3.0

# %%
import torch

print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)
print("GPU:", torch.cuda.get_device_name(0))
# Out:
# Torch version: 2.7.1+cu118
# CUDA available: True
# CUDA version: 11.8
# GPU: NVIDIA GeForce RTX 4060 Laptop GPU
